# %%
import torch 
import os 

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
model_name = 'x3d_s'
model = torch.hub.load('facebookresearch/pytorchvideo', model_name, pretrained=False)
# Out:
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main

# %%
print(model)
# Out:
# Net(
#   (blocks): ModuleList(
#     (0): ResNetBasicStem(
#       (conv): Conv2plus1d(
#         (conv_t): Conv3d(3, 24, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#         (conv_xy): Conv3d(24, 24, kernel_size=(5, 1, 1), stride=(1, 1, 1), padding=(2, 0, 0), groups=24, bias=False)
#       )
#       (norm): BatchNorm3d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#     )
#     (1): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(24, 24, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(24, 54, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
# ...

# %%
from torchinfo import summary

batch_size = 16

summayer = summary(model, input_size=(batch_size, 3, 8, 256, 256))

print(summary)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/torchinfo/torchinfo.py:290, in forward_pass(model, x, batch_dim, cache_forward_pass, device, mode, **kwargs)
#     <a href='file:///usr/local/lib/python3.9/dist-packages/torchinfo/torchinfo.py?line=288'>289</a> if isinstance(x, (list, tuple)):
# --> <a href='file:///usr/local/lib/python3.9/dist-packages/torchinfo/torchinfo.py?line=289'>290</a>     _ = model.to(device)(*x, **kwargs)
#     <a href='file:///usr/local/lib/python3.9/dist-packages/torchinfo/torchinfo.py?line=290'>291</a> elif isinstance(x, dict):
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py:1120, in Module._call_impl(self, *input, **kwargs)
#    <a href='file:///usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py?line=1117'>1118</a>     input = bw_hook.setup_input_hook(input)
# ...

# %%
from torchvision.models import video

model = video.r3d_18(pretrained=False)
# Out:
#   Input In [20]
#     model = video.r3d_18(pretrained=False, class=4)
#                                            ^
# SyntaxError: invalid syntax

# %%
result = summary(model, input_size=(batch_size, 3, 8, 256, 256))

print(result)
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# VideoResNet                              [16, 400]                 --
# ├─BasicStem: 1-1                         [16, 64, 8, 128, 128]     --
# │    └─Conv3d: 2-1                       [16, 64, 8, 128, 128]     28,224
# │    └─BatchNorm3d: 2-2                  [16, 64, 8, 128, 128]     128
# │    └─ReLU: 2-3                         [16, 64, 8, 128, 128]     --
# ├─Sequential: 1-2                        [16, 64, 8, 128, 128]     --
# │    └─BasicBlock: 2-4                   [16, 64, 8, 128, 128]     --
# │    │    └─Sequential: 3-1              [16, 64, 8, 128, 128]     110,720
# │    │    └─Sequential: 3-2              [16, 64, 8, 128, 128]     110,720
# │    │    └─ReLU: 3-3                    [16, 64, 8, 128, 128]     --
# │    └─BasicBlock: 2-5                   [16, 64, 8, 128, 128]     --
# │    │    └─Sequential: 3-4              [16, 64, 8, 128, 128]     110,720
# ...
